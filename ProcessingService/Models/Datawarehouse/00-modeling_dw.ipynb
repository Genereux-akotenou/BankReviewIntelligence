# %%
import pandas as pd

# %%
data = pd.read_parquet('macro_llamma.csv')

# %%
data = pd.read_csv('macro_llamma.csv')

# %%
data.columns
# Out:
# Index(['Country', 'Town', 'Bank_Name', 'Bank_Phone_number', 'Bank_Address',
#        'Bank_Website', 'Reviewer_Nane', 'Reviewer_Sart', 'Reviewer_Text',
#        'Reviewer_Publish_Date', 'Reviewer_Like_Reaction',
#        'Reviewer_Profil_Link', 'Reviewer_Owner_Reply',
#        'Reviewer_Owner_Reply_Date', 'Topic', 'Sentiment', 'Sub_Topic'],
#       dtype='object')

# %%
data.head()
# Out:
#   Country      Town                                Bank_Name  \
# 0   Kenya     Nyeri     Standard Chartered Bank Nyeri Branch
# 1   Kenya     Kitui            Co-Op Bank Atm - Kitui Branch
# 2   Kenya       Voi                                  Kcb Voi
# 3   Kenya    Kitale  Standard Chartered Bank - Kitale Branch
# 4   Kenya  Homa Bay                  Barclays Bank, Homa Bay
#
#   Bank_Phone_number                                       Bank_Address  \
# 0   +254 20 3293900                          Kenyatta Rd, Nyeri, Kenya
# 1   +254 44 4422370   Emco House, Kilungya Makuti Street, Kitui, Kenya
# 2     Not available                                         Voi, Kenya
# 3   +254 20 3293900  Ground Floor- Teryet Business Centre, Kenyatta...
# 4     Not available                          Fff4+7W4, Homa Bay, Kenya
#
#             Bank_Website       Reviewer_Nane  Reviewer_Sart   Reviewer_Text  \
# 0  standardchartered.com                 V M              5             NAN
# ...

# %%
"""
**Tables de Dimensions**

Dimension Region
    Region_ID (Primary Key)
    Country
    Town

Dimension Bank
    Bank_ID (Primary Key)
    Bank_Name
    Bank_Phone_number
    Bank_Address
    Bank_Website

Dimension Reviewer
    Reviewer_ID (Primary Key)
    Reviewer_Name
    Reviewer_Profil_Link
    
Dimension Time
    Time_ID (Primary Key)
    Week
    Month
    Year

Dimension Topic
    Topic_ID
    Label

Dimension SubTopic
    SubTopic_ID
    Label
    
Dimension Sentiment
    Sentiment_ID
    Positive_Sentiment
    Negative_Sentiment
    Neutral_Sentiment

    
**Table de Faits**

- Fact Reviews
    Review_ID (Primary Key)
    Bank_ID (Foreign Key to Dimension Bank)
    Reviewer_ID (Foreign Key to Dimension Reviewer)
    Time_ID (Foreign Key to Dimension Time)
    Topic_ID (Foreign Key to Dimension Time
    Sentiment_ID (Foreign Key to Dimension Time)
    Count_Review
"""
