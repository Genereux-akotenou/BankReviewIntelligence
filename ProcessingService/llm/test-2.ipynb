# %%
from topificator import TopicExtractor
import pandas as pd
from tqdm import tqdm

extractor = TopicExtractor(model="llama3", patience=5)

# %% [markdown]
# * Review Bank

# %%
df = pd.read_parquet('./Rabat.parquet')
df['Topic'] = {}

# %%
df.shape
# Out:
# (20, 15)

# %%
df.head()
# Out:
#    Country   Town                        Bank_Name Bank_Phone_number  \
# 0  Morocco  Rabat        Société De Crédit Vivalis       080-1022222
# 1  Morocco  Rabat               La Banque Mondiale       05376-36050
# 2  Morocco  Rabat                  Crédit du Maroc       05376-74352
# 3  Morocco  Rabat  BMCE BANK Agence Rabat Centrale       05372-16152
# 4  Morocco  Rabat                  Bank Al-Maghrib     Not available
#
#                               Bank_Address   Bank_Website  \
# 0       2589+7F2, Av. Moulay Hassan, Rabat  Not available
# 1  X5G4+4CX, Rue Larbi Ben Abdellah, Rabat  Not available
# 2                                    Rabat  Not available
# 3                260 Av. Mohammed V, Rabat  Not available
# 4          277 Av. Mohammed V, Rabat 10000        bkam.ma
#
#                  Reviewer_Nane  Reviewer_Sart  \
# 0  Mohammed El idrissi kazzouz              2
# 1                  Soad Moroco              4
# 2                Nabil RACHIDI              1
# 3          Driss TAKKI CHEBIHI              4
# 4              mohamed mchatte              4
#
#                                        Reviewer_Text Reviewer_Publish_Date  \
# 0                                                NAN          il y a 5 ans
# 1                                                NAN          il y a 6 ans
# 2  Je ne comprends pas le faite de voir des dizai...         il y a 3 mois
# 3                                                NAN          il y a 7 ans
# 4                                                NAN         il y a 12 ans
#
#    Reviewer_Like_Reaction                               Reviewer_Profil_Link  \
# 0                       0  https://www.google.com/maps/contrib/1092060191...
# 1                       0  https://www.google.com/maps/contrib/1183005452...
# 2                       0  https://www.google.com/maps/contrib/1056241967...
# 3                       0  https://www.google.com/maps/contrib/1149958081...
# 4                       0  https://www.google.com/maps/contrib/1050319361...
#
#    Reviewer_Owner_Reply Reviewer_Owner_Reply_Date Topic
# 0                   NaN                       NAN   NaN
# 1                   NaN                       NAN   NaN
# 2                   NaN                       NAN   NaN
# 3                   NaN                       NAN   NaN
# 4                   NaN                       NAN   NaN

# %% [markdown]
# * Test

# %%
for index, row in tqdm(df.iterrows()):
    review = row['Reviewer_Text']
    
    topics = extractor.extract(review, type='SINGLE_SOURCE')
    print(topics)
    df.at[index, 'Topic'] = str(topics)
# Out:
# 0it [00:00, ?it/s]
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  Je ne comprends pas le faite de voir des dizaines de personnes qui travaillent dans l’agence et on retrouve qu’une seule personne à la caisse on reste presque 40 minutes voir plus pour espérer faire sa opération. Si vous avez 3 caisses ce …
# 3it [01:41, 33.69s/it]
# {'topics': [('organisation du travail', 'Negative', ['40 minutes', 'plus', 'espérer faire sa opération']), ('nombre de personnes', 'Neutral', ['dizaines de personnes', "travaillent dans l'agence"]), ('expérience client', 'Negative', ['rester presque 40 minutes', 'voir plus pour espérer faire sa opération'])]}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  Les employés sont malades mentaux
# 7it [02:25, 18.95s/it]
# {'topics': [('Employés sont malades mentaux', 'Negative', ['malades', 'mentaux'])]}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  33 MAD de frais de retrait
# 20it [03:31, 10.59s/it]
# {'topics': [('Frais de retrait', 'Positive', ['MAD 33'])]}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  NAN
# {'topics': []}
# REVIEW:  NAN
# {'topics': []}

# %% [markdown]
# * Visualization

# %%
df
# Out:
#     Country   Town                            Bank_Name Bank_Phone_number  \
# 0   Morocco  Rabat            Société De Crédit Vivalis       080-1022222
# 1   Morocco  Rabat                   La Banque Mondiale       05376-36050
# 2   Morocco  Rabat                      Crédit du Maroc       05376-74352
# 3   Morocco  Rabat      BMCE BANK Agence Rabat Centrale       05372-16152
# 4   Morocco  Rabat                      Bank Al-Maghrib     Not available
# 5   Morocco  Rabat                             CIH Bank       05376-39305
# 6   Morocco  Rabat                     Banque Populaire     Not available
# 7   Morocco  Rabat             Crédit Agricole du Maroc     Not available
# 8   Morocco  Rabat                            BMCE Bank       05377-76113
# 9   Morocco  Rabat                                 Citi     Not available
# 10  Morocco  Rabat    Banque Populaire (Siège régional)       05372-68200
# 11  Morocco  Rabat        Banque Populaire البنك الشعبي     Not available
# 12  Morocco  Rabat         Banque Populaire Diour Jemaa       05377-25422
# 13  Morocco  Rabat      CFG Bank - Agence Rabat Souissi       05227-76800
# 14  Morocco  Rabat  Banque populaire (Gare Rabat ville)     Not available
# 15  Morocco  Rabat                    Attijariwafa Bank       05377-21181
# 16  Morocco  Rabat          Société Générale BAB EL HAD       05224-24242
# 17  Morocco  Rabat                                 BMCI       05372-18795
# 18  Morocco  Rabat     Société Générale Rabat Michlifen       05224-24242
# 19  Morocco  Rabat                       Bank of Africa       05375-69691
#
#                                          Bank_Address   Bank_Website  \
# 0                  2589+7F2, Av. Moulay Hassan, Rabat  Not available
# 19                                                NAN          il y a 8 ans
#
#     Reviewer_Like_Reaction                               Reviewer_Profil_Link  \
# 0                        0  https://www.google.com/maps/contrib/1092060191...
# 1                        0  https://www.google.com/maps/contrib/1183005452...
# 2                        0  https://www.google.com/maps/contrib/1056241967...
# 3                        0  https://www.google.com/maps/contrib/1149958081...
# 4                        0  https://www.google.com/maps/contrib/1050319361...
# 5                        0  https://www.google.com/maps/contrib/1162662732...
# 6                        0  https://www.google.com/maps/contrib/1020393371...
# 7                        0  https://www.google.com/maps/contrib/1167446290...
# 8                        0  https://www.google.com/maps/contrib/1100191080...
# 9                        0  https://www.google.com/maps/contrib/1042844846...
# 10                       0  https://www.google.com/maps/contrib/1042534939...
# 11                       1  https://www.google.com/maps/contrib/1101928194...
# 12                       0  https://www.google.com/maps/contrib/1163931656...
# 13                       0  https://www.google.com/maps/contrib/1169531668...
# 14                       0  https://www.google.com/maps/contrib/1020213659...
# 15                       0  https://www.google.com/maps/contrib/1091540447...
# 16                       0  https://www.google.com/maps/contrib/1085724517...
# 17                       0  https://www.google.com/maps/contrib/1172059029...
# 18                       0  https://www.google.com/maps/contrib/1150494957...
# 19                       0  https://www.google.com/maps/contrib/1071765876...
#
#     Reviewer_Owner_Reply Reviewer_Owner_Reply_Date  \
# 0                    NaN                       NAN
# 1                    NaN                       NAN
# 2                    NaN                       NAN
# 3                    NaN                       NAN
# 4                    NaN                       NAN
# 5                    NaN                       NAN
# 6                    NaN                       NAN
# 7                    NaN                       NAN
# 8                    NaN                       NAN
# 9                    NaN                       NAN
# 10                   NaN                       NAN
# 11                   NaN                       NAN
# 12                   NaN                       NAN
# 13                   NaN                       NAN
# 14                   NaN                       NAN
# 15                   NaN                       NAN
# 16                   NaN                       NAN
# 17                   NaN                       NAN
# 18                   NaN                       NAN
# 19                   NaN                       NAN
#
#                                                 Topic
# 0                                      {'topics': []}
# 1                                      {'topics': []}
# 2   {'topics': [('organisation du travail', 'Negat...
# 3                                      {'topics': []}
# 4                                      {'topics': []}
# 5                                      {'topics': []}
# 6   {'topics': [('Employés sont malades mentaux', ...
# 7                                      {'topics': []}
# 8                                      {'topics': []}
# 9                                      {'topics': []}
# 10                                     {'topics': []}
# 11  {'topics': [('Frais de retrait', 'Positive', [...
# 12                                     {'topics': []}
# 13                                     {'topics': []}
# 14                                     {'topics': []}
# 15                                     {'topics': []}
# 16                                     {'topics': []}
# 17                                     {'topics': []}
# 18                                     {'topics': []}
# 19                                     {'topics': []}

# %% [markdown]
# <div style="background-color:orange; padding: 0.5em; color: white;">
#     Notice to the developer: This module may return errors due to improper handling. Using it without error management is simply an irresponsible act in production.
# </div>

# %% [markdown]
# **Hahaha**. but we are working to improve it resilience.
